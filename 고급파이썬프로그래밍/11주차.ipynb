# %% [markdown]
# <a href="https://colab.research.google.com/github/hanbinChae/python-learning-univ/blob/main/11%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 모듈

# %%
# 현재시간 출력
import datetime

print(datetime.datetime.now())

# %% [markdown]
# 경과시간 구하기1

# %%
import datetime

print(datetime.datetime.now())
Memorial = datetime.date(2003,1,1)
nowTime = datetime.date.today()
timeDiff = nowTime - Memorial;
print(timeDiff)
# Out:
# 2022-05-19 04:43:54.539898
# 7078 days, 0:00:00

# %% [markdown]
# 실시간 경과시간 구하기2

# %%
from datetime import datetime


startTime = datetime.now()

while True:
    currTime = datetime.now()
    timeDiff = currTime - startTime
    print(timeDiff.seconds)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ...

# %% [markdown]
# micro 초 단위로 경과시간 출력

# %%
from datetime import datetime


startTime = datetime.now()

while True:
    currTime = datetime.now()
    timeDiff = currTime - startTime
    print(timeDiff.microseconds/1000)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 662.866
# 662.895
# 662.922
# 662.948
# 665.175
# 665.238
# 665.271
# 665.301
# 665.331
# 665.361
# 665.39
# 665.42
# 665.45
# 665.48
# 665.509
# 665.538
# 665.567
# 665.596
# 665.625
# 665.654
# 665.697
# 665.727
# 665.757
# 665.787
# 665.815
# 665.844
# 665.874
# 665.903
# 665.929
# 665.956
# 665.984
# 666.01
# 666.037
# 666.062
# 666.091
# 666.117
# 666.145
# 676.847
# 681.16
# 681.227
# 681.272
# 681.304
# 681.334
# 681.364
# 681.396
# 681.423
# 681.452
# 681.483
# 681.513
# 681.543
# 681.569
# 681.6
# 681.653
# 681.703
# 681.731
# 681.759
# 681.789
# 681.819
# 681.849
# 681.88
# 681.91
# 681.937
# 681.967
# 681.996
# 682.026
# 682.056
# 682.086
# 682.112
# 682.142
# 685.051
# 685.136
# 685.173
# 685.204
# 685.237
# 685.268
# 685.299
# 685.336
# 685.366
# 685.396
# 685.426
# 685.454
# 685.485
# 685.516
# 685.546
# 685.582
# 685.613
# 685.643
# 685.67
# 685.725
# 685.755
# 685.786
# 685.816
# 685.845
# 685.875
# 685.905
# 685.934
# 685.965
# ...

# %% [markdown]
# 실제 시간 10초 동안 실행

# %%
import time

startTime = time.time()
while True:
    timeDiff = (time.time() - startTime)
    print(int(timeDiff))
    time.sleep(1.0)
    if timeDiff>10:
        break;
print('종료')
#10초 경과 시 종료

# %% [markdown]
# 거북이 회전 시 0.5초 정지하고 이동

# %%
import time
import turtle

t = turtle.Turtle()
t.shape("turtle")

for i in range(3):
    t.fd(100)
    t.left(120)
    time.sleep(0.5)
    
turtle.exitonclick()
turtle.bye()

# %% [markdown]
# 각도 이동

# %%
import pygame
import turtle

t = turtle.Turtle()
t.shape("turtle")

x = 0
y = 0
x_vel = 4
y_vel = 2

for i in range(100):
    x+=x_vel
    y+=y_vel
    t.goto(x,y)

turtle.exitonclick()
turtle.bye()

# %% [markdown]
# 거북이 화살표 그리기

# %%
import turtle

t = turtle.Turtle()
t.shape('turtle')

pos_list = [[0,0],[0,0],[0,0]]
vel_list = [[-2,0],[0,2],[-2,2]]
t_list = []

for i in range(len(pos_list)):
    t= turtle.Turtle()
    t.shape('turtle')
    t_list.append(t)

for step in range(100):
    for i in range(len(pos_list)):
        pos_list[i][0] += vel_list[i][0]
        pos_list[i][1] += vel_list[i][1]
        t_list[i].goto(pos_list[i][0], pos_list[i][1])
    
turtle.exitonclick()
turtle.bye()

# %% [markdown]
# 외곽선 그리기 함수

# %%
import turtle



SCREEN_WIDTH = 400
SCREEN_HEIGHT = 300

def outline():
    tline = turtle.Turtle()
    
    tline.up()
    tline.goto(SCREEN_WIDTH/2,SCREEN_HEIGHT/2)
    tline.down()
    
    tline.goto(-SCREEN_WIDTH/2,SCREEN_HEIGHT/2)
    tline.goto(-SCREEN_WIDTH/2,-SCREEN_HEIGHT/2)
    tline.goto(SCREEN_WIDTH/2,-SCREEN_HEIGHT/2)
    tline.goto(SCREEN_WIDTH/2,SCREEN_HEIGHT/2)

outline()
turtle.exitonclick()
turtle.bye()

# %% [markdown]
# 소행성 부딪히기 게임

# %%
import turtle
import time

SCREEN_WIDTH = 400
SCREEN_HEIGHT = 300

def outline():
    tline = turtle.Turtle()
    
    tline.up()
    tline.goto(SCREEN_WIDTH/2,SCREEN_HEIGHT/2)
    tline.down()
    
    tline.goto(-SCREEN_WIDTH/2,SCREEN_HEIGHT/2)
    tline.goto(-SCREEN_WIDTH/2,-SCREEN_HEIGHT/2)
    print(-SCREEN_WIDTH/2,-SCREEN_HEIGHT/2)
    tline.goto(SCREEN_WIDTH/2,-SCREEN_HEIGHT/2)
    tline.goto(SCREEN_WIDTH/2,SCREEN_HEIGHT/2)

outline()

loc=[[0,0],[0,0]]
vel=[[5,5],[5,-5]]
asteroid_list = []
startTime = time.time()

for i in range(len(loc)):
    t = turtle.Turtle()
    t.shape("circle")
    t.goto(loc[i][0],loc[i][1])
    asteroid_list.append(t)

for i in range(200):
   for i in range(len(loc)):
        loc[i][0]+=vel[i][0]
        loc[i][1]+=vel[i][1]
        
        asteroid_list[i].goto(loc[i][0],loc[i][1])
        
        if loc[i][0]>=SCREEN_WIDTH/2:
            vel[i][0] = -vel[i][0]
        
        if loc[i][0]<=-SCREEN_WIDTH/2:
            vel[i][0] = -vel[i][0]
        
        if loc[i][1]>=SCREEN_HEIGHT/2:
            vel[i][1] = -vel[i][1]
        
        if loc[i][1]<=-SCREEN_HEIGHT/2:
            vel[i][1]= -vel[i][1]
            
timeDiff = time.time()-startTime
turtle.write(timeDiff)

turtle.exitonclick()
turtle.bye()
