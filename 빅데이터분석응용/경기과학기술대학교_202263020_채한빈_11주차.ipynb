# %% [markdown]
# # 1차시

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = sns.load_dataset("iris")
iris = iris.drop('species',axis=1)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris1 = iris.iloc[0]
iris1
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
iris1.plot.pie()
# pie() : 각 비율을 나타낸 차트
# Out:
# <AxesSubplot:ylabel='0'>

# %%
iris2 = iris.iloc[0:3]
iris2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2

# %%
iris2.plot.pie()
# pie() : 값이 많을 경우 subplots = True로 설정해야 한다.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 iris2.plot.pie()
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1583, in PlotAccessor.pie(self, **kwargs)
#    1532 """
#    1533 Generate a pie plot.
#    1534
#    (...)
#    1576     >>> plot = df.plot.pie(subplots=True, figsize=(11, 6))
#    1577 """
#    1578 if (
#    1579     isinstance(self._parent, ABCDataFrame)
#    1580     and kwargs.get("y", None) is None
#    1581     and not kwargs.get("subplots", False)
#    1582 ):
# -> 1583     raise ValueError("pie requires either y column or 'subplots=True'")
#    1584 return self(kind="pie", **kwargs)
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
iris2.plot.pie(subplots = True)
# pie() : 값이 많을 경우 subplots = True로 설정해야 한다.
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
iris2.T.plot.pie(subplots = True, figsize=(15,15))
# == iris2.transpose()
# 행과 열 변환
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris2.T
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
iris2.T.plot.pie(subplots = True, figsize=(15,15),fontsize=15)
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris2.T.plot.pie(subplots = True, figsize=(15,15),fontsize=15, autopct="%.2f")
# autopct="%f" : 차트 안에 백분율로 표시
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
iris2.T.plot.pie(subplots = True, figsize=(15,15),fontsize=15, autopct="%.2f%%")
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
pd.plotting.scatter_matrix(iris,figsize=(7,7), diagonal='kde', color='red')
# scatter_matrix : 두 데이터와의 관계 한눈에 확인
#diagonal='kde' : 데이터 분포 형태 지정
# Out:
# array([[<AxesSubplot:xlabel='sepal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='sepal_width'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='sepal_width'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_length', ylabel='petal_length'>,
#         <AxesSubplot:xlabel='petal_width', ylabel='petal_length'>],
#        [<AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>,
#         <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>,
# ...
