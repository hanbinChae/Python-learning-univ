# %% [markdown]
# # 11주차 과제

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
auto = pd.read_csv("data/auto-mpg.csv")

# %%
auto = auto.squeeze()
auto
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mpg     392 non-null    float64
#  1   cyl     392 non-null    int64
#  2   displ   392 non-null    float64
#  3   hp      392 non-null    int64
#  4   weight  392 non-null    int64
#  5   accel   392 non-null    float64
#  6   yr      392 non-null    int64
#  7   origin  392 non-null    int64
#  8   name    392 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 27.7+ KB

# %%
auto.iloc[:,:4].plot()
# Out:
# <AxesSubplot:>

# %%
auto.iloc[0,:4].plot.bar()
# Out:
# <AxesSubplot:>

# %%
auto.iloc[:,:4].plot.hist(bins=5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
auto.iloc[:,:4].plot.box()
# 각 선은 데이터의 위치를 나타낸다.
# 즉 가장 위 선분은 최대값, 제일 밑에 위치한 선분은 최소값
# 최대값 밑에서부터 각각 75%, 25% 위치에 선분이 표시되고,
#초록색 선분은 중앙값을 나타낸다.
# hp열의 최대값을 나타내는 선분 위에있는 모양은 결측치를 나타낸다.
# Out:
# <AxesSubplot:>

# %%
auto.iloc[:,:3].plot.scatter(x='mpg', y='cyl', c='displ')
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='cyl'>

# %%
pd.plotting.scatter_matrix(auto.iloc[:,:4])
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cyl', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displ', ylabel='mpg'>,
#         <AxesSubplot:xlabel='hp', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cyl'>,
#         <AxesSubplot:xlabel='cyl', ylabel='cyl'>,
#         <AxesSubplot:xlabel='displ', ylabel='cyl'>,
#         <AxesSubplot:xlabel='hp', ylabel='cyl'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='displ'>,
#         <AxesSubplot:xlabel='cyl', ylabel='displ'>,
#         <AxesSubplot:xlabel='displ', ylabel='displ'>,
#         <AxesSubplot:xlabel='hp', ylabel='displ'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='hp'>,
#         <AxesSubplot:xlabel='cyl', ylabel='hp'>,
#         <AxesSubplot:xlabel='displ', ylabel='hp'>,
#         <AxesSubplot:xlabel='hp', ylabel='hp'>]], dtype=object)

# %%
auto.iloc[:,:4].plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)
