# %%
import pandas as pd
import numpy as no
import seaborn as sns
import matplotlib.pyplot as plt

# %%
satis = pd.read_csv("data/satisfaction.csv")
x = satis['id']
y = satis['Satisfaction Rating']

# %%
plt.plot(x,y)

# %%
plt.plot(x,y, marker='o', markersize=7)
plt.title('Assignment 2')
# Out:
# Text(0.5, 1.0, 'Assignment 2')
